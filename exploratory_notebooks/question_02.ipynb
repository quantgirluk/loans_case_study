# %% [markdown]
# Question 2: Please add the following calculated columns to the dataframe (plus any others you found helpful).
#
# Dynamic Columns (These vary by loan and by calendar month):
#
# - current_balance: The current balance outstanding for each loan and month.
# - seasoning: The integer number of months since the loan was originated at each month.
# - n_missed_payments: number of missed payments in a row.
# - prepaid_in_month: a flag indicating that the borrower prepaid in a given month.
# - default_in_month: a flag indicating that the borrower defaulted in a given month.
# - recovery_in_month: a flag indicating that a recovery has been made post-default in a given month.
# - is_recovery_payment: a flag indicating whether the associated payment has been made post-default.
# - time_to_reversion: The integer number of months until the laon reverts. This is negative if the - loan is before reversion and 0 at the month of reversion.
# - is_post_seller_purchsae_date: Is this time period after the seller purchased this loan.

# %%
import pandas as pd
from case_functions import consolidate_data

# %%
pd.options.display.float_format = "{:,.2f}".format

# %%
data = consolidate_data()

# %%
data['Payment_Made'] = data['Payment_Made'].fillna(0)

# %%
data.head()
# Out:
#    loan_id    level_1    Balance  Payment_Due  Payment_Made origination_date  \
# 0        1 2020-12-31 150,876.00          NaN          0.00       2020-12-31
# 1        1 2021-01-31 150,876.00       249.96        249.96       2020-12-31
# 2        1 2021-02-28 150,876.00       249.96        249.96       2020-12-31
# 3        1 2021-03-31 150,876.00       249.96        249.96       2020-12-31
# 4        1 2021-04-30 150,876.00       249.96        249.96       2020-12-31
#
#   investor_1_acquisition_date reversion_date  original_balance  product  \
# 0                  2020-12-31     2022-12-31            150876        1
# 1                  2020-12-31     2022-12-31            150876        1
# 2                  2020-12-31     2022-12-31            150876        1
# 3                  2020-12-31     2022-12-31            150876        1
# 4                  2020-12-31     2022-12-31            150876        1
#
#    pre_reversion_fixed_rate  post_reversion_boe_margin
# 0                      0.02                       0.04
# 1                      0.02                       0.04
# 2                      0.02                       0.04
# 3                      0.02                       0.04
# 4                      0.02                       0.04

# %%
data['payment_made_cumsum'] = data.groupby("loan_id")['Payment_Made'].cumsum()

# %%
data['current_balance'] = data['original_balance'] - data['payment_made_cumsum']

# %%
data['level_1'] - data['origination_date']  # This give us days
# Out:
# 0         0 days
# 1        31 days
# 2        59 days
# 3        90 days
# 4       120 days
#           ...
# 42606    92 days
# 42607   122 days
# 42608   153 days
# 42609   183 days
# 42610   214 days
# Length: 42611, dtype: timedelta64[ns]

# %%
data['seasoning'] = data['level_1'].dt.to_period('M').astype(int) - data['origination_date'].dt.to_period('M').astype(int)

# %% [markdown]
# Question/Assumption
#
# - I am going to assume that a payment which not zero but less than the amount due is a missed payment.
# - There is only 1 instance this happens.

# %%
data [ (data['Payment_Due'] > data['Payment_Made'] ) & data['Payment_Made']>0]
# Out:
#        loan_id    level_1    Balance  Payment_Due  Payment_Made  \
# 21680      905 2021-09-30 148,652.00       476.93        280.89
#
#       origination_date investor_1_acquisition_date reversion_date  \
# 21680       2019-08-31                  2020-12-31     2021-08-31
#
#        original_balance  product  pre_reversion_fixed_rate  \
# 21680            148652        1                      0.02
#
#        post_reversion_boe_margin  payment_made_cumsum  current_balance  \
# 21680                       0.04             6,741.40       141,910.60
#
#        seasoning
# 21680         25

# %%
data['missed_payment'] = data['Payment_Due'] > data['Payment_Made']

# %%
data['not_missed'] = ~data['missed_payment']

# %%
#  = data.groupby("loan_id")['missed_payment'].cumsum()

# %%
# data.groupby('loan_id')['not_missed'].cumsum()

# %%
# (~data['missed_payment']).cumsum()

# %%
data['n_missed_payments'] = data['missed_payment'].groupby((~data['missed_payment']).cumsum()).cumsum()

# %%
data[data.n_missed_payments >=3]['loan_id'].unique()
# Out:
# array([   3,   38,   52,   89,   92,   93,  154,  178,  199,  208,  212,
#         222,  227,  292,  299,  313,  338,  361,  372,  429,  445,  469,
#         478,  512,  516,  577,  614,  641,  648,  666,  681,  685,  692,
#         696,  702,  704,  706,  748,  835,  844,  846,  855,  864,  903,
#         946,  974,  996, 1085, 1119, 1120, 1177, 1188, 1212, 1215, 1239,
#        1331, 1372, 1386, 1397, 1430, 1433, 1560, 1567, 1606])

# %%
data[data.loan_id == 1606]
# Out:
#        loan_id    level_1    Balance  Payment_Due  Payment_Made  \
# 41738     1606 2021-11-30 215,105.00          NaN          0.00
# 41739     1606 2021-12-31 215,105.00       543.95        543.95
# 41740     1606 2022-01-31 215,105.00       543.95        543.95
# 41741     1606 2022-02-28 215,105.00       543.95        543.95
# 41742     1606 2022-03-31 215,105.00       543.95          0.00
# 41743     1606 2022-04-30 215,105.00       543.95      1,087.91
# 41744     1606 2022-05-31 215,105.00       543.95        543.95
# 41745     1606 2022-06-30 215,105.00       543.95        543.95
# 41746     1606 2022-07-31 215,105.00       543.95          0.00
# 41747     1606 2022-08-31 215,105.00       543.95          0.00
# 41748     1606 2022-09-30 215,105.00       543.95          0.00
# 41749     1606 2022-10-31 215,105.00       543.95          0.00
# 41750     1606 2022-11-30 215,105.00       543.95          0.00
# 41751     1606 2022-12-31       0.00       543.95    129,665.97
#
#       origination_date investor_1_acquisition_date reversion_date  \
# 41738       2021-11-30                  2021-11-30     2023-11-30
# 41739       2021-11-30                  2021-11-30     2023-11-30
# 41740       2021-11-30                  2021-11-30     2023-11-30
# 41741       2021-11-30                  2021-11-30     2023-11-30
# 41742       2021-11-30                  2021-11-30     2023-11-30
# 41743       2021-11-30                  2021-11-30     2023-11-30
# 41744       2021-11-30                  2021-11-30     2023-11-30
# 41745       2021-11-30                  2021-11-30     2023-11-30
# 41746       2021-11-30                  2021-11-30     2023-11-30
# 41747       2021-11-30                  2021-11-30     2023-11-30
# 41748       2021-11-30                  2021-11-30     2023-11-30
# 41749       2021-11-30                  2021-11-30     2023-11-30
# 41750       2021-11-30                  2021-11-30     2023-11-30
# 41751       2021-11-30                  2021-11-30     2023-11-30
#
#        original_balance  product  pre_reversion_fixed_rate  \
# 41738            215105        2                      0.03
# 41739            215105        2                      0.03
# 41740            215105        2                      0.03
# 41741            215105        2                      0.03
# 41742            215105        2                      0.03
# 41743            215105        2                      0.03
# 41744            215105        2                      0.03
# 41745            215105        2                      0.03
# 41746            215105        2                      0.03
# 41747            215105        2                      0.03
# 41748            215105        2                      0.03
# 41749            215105        2                      0.03
# 41750            215105        2                      0.03
# 41751            215105        2                      0.03
#
#        post_reversion_boe_margin  payment_made_cumsum  current_balance  \
# 41738                       0.02                 0.00       215,105.00
# 41739                       0.02               543.95       214,561.05
# 41740                       0.02             1,087.91       214,017.09
# 41741                       0.02             1,631.86       213,473.14
# 41742                       0.02             1,631.86       213,473.14
# 41743                       0.02             2,719.77       212,385.23
# 41744                       0.02             3,263.73       211,841.27
# 41745                       0.02             3,807.68       211,297.32
# 41746                       0.02             3,807.68       211,297.32
# 41747                       0.02             3,807.68       211,297.32
# 41748                       0.02             3,807.68       211,297.32
# 41749                       0.02             3,807.68       211,297.32
# 41750                       0.02             3,807.68       211,297.32
# 41751                       0.02           133,473.66        81,631.34
#
#        seasoning  missed_payment  not_missed  n_missed_payments
# 41738          0           False        True                  0
# 41739          1           False        True                  0
# 41740          2           False        True                  0
# 41741          3           False        True                  0
# 41742          4            True       False                  1
# 41743          5           False        True                  0
# 41744          6           False        True                  0
# 41745          7           False        True                  0
# 41746          8            True       False                  1
# 41747          9            True       False                  2
# 41748         10            True       False                  3
# 41749         11            True       False                  4
# 41750         12            True       False                  5
# 41751         13           False        True                  0

# %%
# data['missed_payment'].groupby((~data['missed_payment']).cumsum()).cumsum()

# %% [markdown]
# - prepaid_in_month: a flag indicating that the borrower prepaid in a given month.
#
# Prepayment: The full and early prepayment of a mortgage.

# %%
data['prepaid_in_month'] = (data['Payment_Due'] < data['Payment_Made']) & (data['Balance'] == 0)

# %%
data[(data.prepaid_in_month == True)]
# Out:
#        loan_id    level_1  Balance  Payment_Due  Payment_Made  \
# 8            1 2021-08-31     0.00       249.96    151,125.96
# 108          3 2022-07-31     0.00       372.13     88,870.54
# 220          7 2022-11-30     0.00       165.84     88,191.84
# 308         10 2021-10-31     0.00       205.00     64,102.00
# 351         13 2021-05-31     0.00       109.09     55,780.09
# ...        ...        ...      ...          ...           ...
# 40343     1567 2021-12-31     0.00         0.00     65,444.94
# 41395     1594 2021-08-31     0.00       263.25    150,689.25
# 41751     1606 2022-12-31     0.00       543.95    129,665.97
# 41968     1614 2022-09-30     0.00       307.20     87,047.20
# 42003     1615 2022-06-30     0.00       187.18     69,301.18
#
#       origination_date investor_1_acquisition_date reversion_date  \
# 8           2020-12-31                  2020-12-31     2022-12-31
# 108         2018-02-28                  2020-12-31     2020-02-28
# 220         2021-06-30                  2021-06-30     2023-06-30
# 308         2017-06-30                  2020-12-31     2019-06-30
# 351         2021-04-30                  2021-04-30     2023-04-30
# ...                ...                         ...            ...
# 40343       2020-03-31                  2020-12-31     2022-03-31
# 41395       2016-11-30                  2020-12-31     2018-11-30
# 41751       2021-11-30                  2021-11-30     2023-11-30
# 41968       2016-01-31                  2020-12-31     2018-01-31
# 42003       2019-11-30                  2020-12-31     2021-11-30
#
#        original_balance  product  pre_reversion_fixed_rate  \
# 8                150876        1                      0.02
# 108               89311        1                      0.03
# 220               88026        1                      0.02
# 308               63897        1                      0.03
# 351               55671        1                      0.02
# ...                 ...      ...                       ...
# 40343             80728        2                      0.02
# 41395            150426        2                      0.02
# 41751            215105        2                      0.03
# 41968             86740        2                      0.03
# 42003             69114        2                      0.03
#
#        post_reversion_boe_margin  payment_made_cumsum  current_balance  \
# 8                           0.04           152,875.68        -1,999.68
# 108                         0.04           100,838.98       -11,527.98
# 220                         0.04            90,845.20        -2,819.20
# 308                         0.04            73,214.78        -9,317.78
# 351                         0.04            55,780.09          -109.09
# ...                          ...                  ...              ...
# 40343                       0.02            67,573.37        13,154.63
# 41395                       0.02           167,564.71       -17,138.71
# 41751                       0.02           133,473.66        81,631.34
# 41968                       0.02           101,316.97       -14,576.97
# 42003                       0.02            73,650.95        -4,536.95
#
#        seasoning  missed_payment  not_missed  n_missed_payments  \
# 8              8           False        True                  0
# 108           53           False        True                  0
# 220           17           False        True                  0
# 308           52           False        True                  0
# 351            1           False        True                  0
# ...          ...             ...         ...                ...
# 40343         21           False        True                  0
# 41395         57           False        True                  0
# 41751         13           False        True                  0
# 41968         80           False        True                  0
# 42003         31           False        True                  0
#
#        prepaid_in_month
# 8                  True
# 108                True
# 220                True
# 308                True
# 351                True
# ...                 ...
# 40343              True
# 41395              True
# 41751              True
# 41968              True
# 42003              True
#
# [330 rows x 19 columns]

# %% [markdown]
# - default_in_month: a flag indicating that the borrower defaulted in a given month.
# - Default: The borrower misses three payments in a row. Borrowers cannot be cured from defaults.

# %%
data['default_in_month'] = (data.n_missed_payments == 3)

# %% [markdown]
# - recovery_in_month: a flag indicating that a recovery has been made post-default in a given month.
# - Recovery: Any payments made post being flagged as default.

# %%
data['default_in_month_cumsum'] = data.default_in_month.cumsum()

# %%
data[data.loan_id == 1606]
# Out:
#        loan_id    level_1    Balance  Payment_Due  Payment_Made  \
# 41738     1606 2021-11-30 215,105.00          NaN          0.00
# 41739     1606 2021-12-31 215,105.00       543.95        543.95
# 41740     1606 2022-01-31 215,105.00       543.95        543.95
# 41741     1606 2022-02-28 215,105.00       543.95        543.95
# 41742     1606 2022-03-31 215,105.00       543.95          0.00
# 41743     1606 2022-04-30 215,105.00       543.95      1,087.91
# 41744     1606 2022-05-31 215,105.00       543.95        543.95
# 41745     1606 2022-06-30 215,105.00       543.95        543.95
# 41746     1606 2022-07-31 215,105.00       543.95          0.00
# 41747     1606 2022-08-31 215,105.00       543.95          0.00
# 41748     1606 2022-09-30 215,105.00       543.95          0.00
# 41749     1606 2022-10-31 215,105.00       543.95          0.00
# 41750     1606 2022-11-30 215,105.00       543.95          0.00
# 41751     1606 2022-12-31       0.00       543.95    129,665.97
#
#       origination_date investor_1_acquisition_date reversion_date  \
# 41738       2021-11-30                  2021-11-30     2023-11-30
# 41739       2021-11-30                  2021-11-30     2023-11-30
# 41740       2021-11-30                  2021-11-30     2023-11-30
# 41741       2021-11-30                  2021-11-30     2023-11-30
# 41742       2021-11-30                  2021-11-30     2023-11-30
# 41743       2021-11-30                  2021-11-30     2023-11-30
# 41744       2021-11-30                  2021-11-30     2023-11-30
# 41745       2021-11-30                  2021-11-30     2023-11-30
# 41746       2021-11-30                  2021-11-30     2023-11-30
# 41747       2021-11-30                  2021-11-30     2023-11-30
# 41748       2021-11-30                  2021-11-30     2023-11-30
# 41749       2021-11-30                  2021-11-30     2023-11-30
# 41750       2021-11-30                  2021-11-30     2023-11-30
# 41751       2021-11-30                  2021-11-30     2023-11-30
#
#        original_balance  product  ...  post_reversion_boe_margin  \
# 41738            215105        2  ...                       0.02
# 41739            215105        2  ...                       0.02
# 41740            215105        2  ...                       0.02
# 41741            215105        2  ...                       0.02
# 41742            215105        2  ...                       0.02
# 41743            215105        2  ...                       0.02
# 41744            215105        2  ...                       0.02
# 41745            215105        2  ...                       0.02
# 41746            215105        2  ...                       0.02
# 41747            215105        2  ...                       0.02
# 41748            215105        2  ...                       0.02
# 41749            215105        2  ...                       0.02
# 41750            215105        2  ...                       0.02
# 41751            215105        2  ...                       0.02
#
#        payment_made_cumsum  current_balance  seasoning  missed_payment  \
# 41738                 0.00       215,105.00          0           False
# 41739               543.95       214,561.05          1           False
# 41740             1,087.91       214,017.09          2           False
# 41741             1,631.86       213,473.14          3           False
# 41742             1,631.86       213,473.14          4            True
# 41743             2,719.77       212,385.23          5           False
# 41744             3,263.73       211,841.27          6           False
# 41745             3,807.68       211,297.32          7           False
# 41746             3,807.68       211,297.32          8            True
# 41747             3,807.68       211,297.32          9            True
# 41748             3,807.68       211,297.32         10            True
# 41749             3,807.68       211,297.32         11            True
# 41750             3,807.68       211,297.32         12            True
# 41751           133,473.66        81,631.34         13           False
#
#        not_missed  n_missed_payments  prepaid_in_month  default_in_month  \
# 41738        True                  0             False             False
# 41739        True                  0             False             False
# 41740        True                  0             False             False
# 41741        True                  0             False             False
# 41742       False                  1             False             False
# 41743        True                  0             False             False
# 41744        True                  0             False             False
# 41745        True                  0             False             False
# 41746       False                  1             False             False
# 41747       False                  2             False             False
# 41748       False                  3             False              True
# 41749       False                  4             False             False
# 41750       False                  5             False             False
# 41751        True                  0              True             False
#
#        default_in_month_cumsum
# 41738                       63
# 41739                       63
# 41740                       63
# 41741                       63
# 41742                       63
# 41743                       63
# 41744                       63
# 41745                       63
# 41746                       63
# 41747                       63
# 41748                       64
# 41749                       64
# 41750                       64
# 41751                       64
#
# [14 rows x 21 columns]

# %% [markdown]
# - is_recovery_payment: a flag indicating whether the associated payment has been made post-default.

# %%
# - is_recovery_payment: a flag indicating whether the associated payment has been made post-default.

# %%
data[data.n_missed_payments > 2]['loan_id'].unique()

# %%
data[data.loan_id == 1606]

# %%
df = data[data.loan_id == 1606]
df.missed_payment

# %% [markdown]
# - time_to_reversion: The integer number of months until the laon reverts. This is negative if the - loan is before reversion and 0 at the month of reversion.
